# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
cdt_card = pd.read_csv('/content/BankChurners.csv')

# %%
cdt_card.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
cdt_card.columns = ['num_cliente', 'cliente_ativo', 'idade', 'genero',
       'dependentes', 'escolaridade', 'estado_civil',
       'renda_anual', 'categoria_cartao', 'meses_relacionamento',
       'total_produtos', 'meses_inativos_12meses',
       'contatos_12meses', 'limite_credito', 'saldocrd_rotativo',
       'avg_credito_comprar', 'mud_trans_Q4_Q1', 'total_trans_qtd',
       'total_trans_count', 'total_ct_change_Q4_Q1', 'avg_utilization_card',
       'naive_bayes_mon_1', 'naive_bayes_mon_2']

# %%
## verificando as informações do dataframe

# %%
cdt_card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   num_cliente             10127 non-null  int64
#  1   cliente_ativo           10127 non-null  object
#  2   idade                   10127 non-null  int64
#  3   genero                  10127 non-null  object
#  4   dependentes             10127 non-null  int64
#  5   escolaridade            10127 non-null  object
#  6   estado_civil            10127 non-null  object
#  7   renda_anual             10127 non-null  object
#  8   categoria_cartao        10127 non-null  object
#  9   meses_relacionamento    10127 non-null  int64
#  10  total_produtos          10127 non-null  int64
#  11  meses_inativos_12meses  10127 non-null  int64
#  12  contatos_12meses        10127 non-null  int64
#  13  limite_credito          10127 non-null  float64
# ...

# %%
# verificando qual a maior incidência entre os gêneros

# %%
cdt_card['genero'].value_counts()
# Out:
# genero
# F    5358
# M    4769
# Name: count, dtype: int64

# %%
sns.countplot(data=cdt_card, x='genero')
# Out:
# <Axes: xlabel='genero', ylabel='count'>

# %%
cdt_card
# Out:
#        num_cliente      cliente_ativo  idade genero  dependentes escolaridade  \
# 0        768805383  Existing Customer     45      M            3  High School
# 1        818770008  Existing Customer     49      F            5     Graduate
# 2        713982108  Existing Customer     51      M            3     Graduate
# 3        769911858  Existing Customer     40      F            4  High School
# 4        709106358  Existing Customer     40      M            3   Uneducated
# ...            ...                ...    ...    ...          ...          ...
# 10122    772366833  Existing Customer     50      M            2     Graduate
# 10123    710638233  Attrited Customer     41      M            2      Unknown
# 10124    716506083  Attrited Customer     44      F            1  High School
# 10125    717406983  Attrited Customer     30      M            2     Graduate
# 10126    714337233  Attrited Customer     43      F            2     Graduate
#
# ...

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='idade', y='renda_anual', data=cdt_card)
plt.title('Variação da Renda Anual entre Diferentes Faixas Etárias')
plt.xlabel('Faixa Etária')
plt.ylabel('Renda Anual')
plt.show()

# %%
cdt_card['idade'].max()
# Out:
# 73

# %%
cdt_card['idade'].min()
# Out:
# 26

# %%
fig = px.box(cdt_card, x='idade', y='renda_anual', title='Variação da Renda Anual entre Diferentes Faixas Etárias',
             labels={'idade': 'Faixa Etária', 'renda_anual': 'Renda Anual'},
             category_orders={'idade': labels})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cdt_card.sort_values(by=('idade')).tail(30)
# Out:
#       num_cliente      cliente_ativo  idade genero  dependentes escolaridade  \
# 2275    708590658  Existing Customer     65      F            1      Unknown
# 2282    710458758  Existing Customer     65      F            0     Graduate
# 4085    780105483  Attrited Customer     65      F            0   Uneducated
# 4304    713168733  Existing Customer     65      F            0      Unknown
# 3297    711861258  Existing Customer     65      F            1   Uneducated
# 3784    708887433  Existing Customer     65      M            0     Graduate
# 1292    714547458  Existing Customer     65      M            0     Graduate
# 5815    718693683  Existing Customer     65      F            0  High School
# 1227    807244983  Existing Customer     65      F            0      College
# 1228    821872758  Existing Customer     65      M            0  High School
# 2722    711076533  Existing Customer     65      M            0      College
# ...

# %%
cdt_card.sort_values(by=('idade')).head(30)
# Out:
#       num_cliente      cliente_ativo  idade genero  dependentes escolaridade  \
# 910     809342208  Existing Customer     26      M            0     Graduate
# 1462    771556308  Existing Customer     26      F            0  High School
# 1592    714248733  Existing Customer     26      F            0      Unknown
# 5462    711336033  Existing Customer     26      F            0      Unknown
# 1908    710934033  Existing Customer     26      M            0  High School
# 7258    709077933  Existing Customer     26      F            0  High School
# 1375    719139558  Existing Customer     26      M            0   Uneducated
# 2783    779342958  Existing Customer     26      F            0      College
# 2180    716800908  Existing Customer     26      F            2  High School
# 2138    710363433  Existing Customer     26      M            0  High School
# 8411    712407033  Existing Customer     26      F            0   Uneducated
# ...

# %%
cdt_card['estado_civil'].value_counts()
# Out:
# estado_civil
# Married     4687
# Single      3943
# Unknown      749
# Divorced     748
# Name: count, dtype: int64

# %%
cdt_card['categoria_cartao'].value_counts()
# Out:
# categoria_cartao
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: count, dtype: int64

# %%
sns.catplot(
    cdt_card, kind="bar",
    x="estado_civil", y="faixa_etaria", col="categoria_cartao",
    height=12, aspect=.4,
)

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=cdt_card, x='estado_civil', hue='categoria_cartao')
plt.title('Distribuição do Tipo de Cartão entre os Diferentes Estados Civis')
plt.xlabel('Estado Civil')
plt.ylabel('Contagem')
plt.legend(title='Tipo de Cartão')
plt.show()

# %%
fig = px.histogram(cdt_card, x='estado_civil', color='categoria_cartao', barmode='group',
                   title='Distribuição do Tipo de Cartão entre os Diferentes Estados Civis',
                   labels={'estado_civil': 'Estado Civil', 'count': 'Contagem', 'categoria_cartao': 'Tipo de Cartão'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
cdt_card['renda_anual'].value_counts()
# Out:
# renda_anual
# Less than $40K    3561
# $40K - $60K       1790
# $80K - $120K      1535
# $60K - $80K       1402
# Unknown           1112
# $120K +            727
# Name: count, dtype: int64

# %%
cdt_card['limite_credito'].value_counts()
# Out:
# limite_credito
# 34516.0    508
# 1438.3     507
# 9959.0      18
# 15987.0     18
# 23981.0     12
#           ...
# 9183.0       1
# 29923.0      1
# 9551.0       1
# 11558.0      1
# 10388.0      1
# Name: count, Length: 6205, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='renda_anual', y='limite_credito', data=cdt_card)
plt.title('Variação do Limite Liberado com a Renda Anual')
plt.xlabel('Renda Anual')
plt.ylabel('Limite Liberado')
plt.show()

# %%
fig = px.scatter(cdt_card, x='renda_anual', y='limite_credito', title='Variação do Limite Liberado com a Renda Anual',
                 labels={'renda_anual': 'Renda Anual', 'limite_credito': 'Limite Liberado'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.box(cdt_card, x='genero', y='limite_credito', title='Distribuição do Limite Liberado por Gênero',
             labels={'genero': 'Gênero', 'limite_credito': 'Limite Liberado'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=cdt_card, x='genero', hue='categoria_cartao')
plt.title('Distribuição do Tipo de Cartão por Gênero')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.legend(title='Tipo de Cartão')
plt.show()
